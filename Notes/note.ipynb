# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Ek line mein summary
setup.py + pip install -e . = Python ko bolta hai ki tumhara src/ folder ek proper package hai, jise kahin se bhi import kiya ja sakta hai — bina path jugaad ke. Ye wahi foundation hai jis pe baaki saara clean import structure tika hota hai.
