# %% [markdown]
# hmlog locally run kr liye hain application.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip freeze> requirements.txt bhi kr diye.

# %% [markdown]
# now 1. we can deploy directly using github and render.com
# that we have done for one of application.

# %% [markdown]
# here we will try to do something else.
# local code---github push --azure deployment.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
